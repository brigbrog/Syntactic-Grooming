# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

import bout_vis

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
asd_bouts_fpath = '/Users/brogab/Documents/JAXFell25/data/syntactic_grooming_raw/asd_bouts_08232024.csv'
bxd_bouts_fpath = '/Users/brogab/Documents/JAXFell25/data/syntactic_grooming_raw/bxd_bouts_08232024.csv'
jab_bouts_fpath = '/Users/brogab/Documents/JAXFell25/data/syntactic_grooming_raw/jabs1200_bouts_08232024.csv'

# %%
bxd_df = pd.read_csv(bxd_bouts_fpath)

bxd_df.head()
# Out:
#    Start  Duration  State                                         Video_name  \
# 0      0      3782      6  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 1   3782       141      3  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 2   3923        87      6  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 3   4010        70      3  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 4   4080        16      6  /projects/kumar-lab/bxd-survey-dataset/unalign...
#
#                                      NetworkFilename       Strain Sex   End  \
# 0  LL1-B2B/2019-06-25_SPD/LL1-1_030878-M-AX10-8.7...  BXD194/RwwJ   M  3782
# 1  LL1-B2B/2019-06-25_SPD/LL1-1_030878-M-AX10-8.7...  BXD194/RwwJ   M  3923
# 2  LL1-B2B/2019-06-25_SPD/LL1-1_030878-M-AX10-8.7...  BXD194/RwwJ   M  4010
# 3  LL1-B2B/2019-06-25_SPD/LL1-1_030878-M-AX10-8.7...  BXD194/RwwJ   M  4080
# 4  LL1-B2B/2019-06-25_SPD/LL1-1_030878-M-AX10-8.7...  BXD194/RwwJ   M  4096
#
# ...

# %%
bout_vis.vid_filtstate_view_w_time(bxd_df, [0, 1])

# %%
window = (28500, 29500)
bout_vis.manual_inspect_filtstate(bxd_df, 1, window)

# %%
bout_vis.rost_caud_filtstate_view(bxd_df, [0, 1])
#bout_vis.vid_filtstate_view_w_time(bxd_df, [0, 1])

# %%
print(bout_vis.rost_caud_simplify(0))
# Out:
# 1

# %%
window = (20000, 30000)
bout_vis.manual_inspect_rost_caud_filtstate(bxd_df, 1, window)

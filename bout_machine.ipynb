# %%
import pandas as pd
import numpy as np

from bout_machine import BoutMachine
import visualize.bout_vis as bout_vis
from FileCurtain import FileCurtain

# %load_ext autoreload
# %autoreload 2

# %%
groomFileCurtain = FileCurtain('/Users/brogab/Documents/JAXFell25/library/groom_pathlib.txt')

fakeFileCurtain = FileCurtain('/Users/brogab/Documents/JAXFell25/library/fake_pathlib.txt')

# %%
fake_fpath = fakeFileCurtain.fpaths['fake1']

asd_bouts_fpath = groomFileCurtain.fpaths['ASD_bouts']
bxd_bouts_fpath = groomFileCurtain.fpaths['BXD_bouts']
jab_bouts_fpath = groomFileCurtain.fpaths['JABS1200']

# %% [markdown]
# run for fake data

# %%
fake = pd.read_csv(fake_fpath)

fake.head(10)
# Out:
#    Start  Duration  State  Video_name NetworkFilename  Strain  Sex  End  \
# 0      0        50      0  fake video       fake file     NaN  NaN   50
# 1     50         2      1  fake video       fake file     NaN  NaN   52
# 2     52         2      2  fake video       fake file     NaN  NaN   54
# 3     54         2      3  fake video       fake file     NaN  NaN   56
# 4     56         2      4  fake video       fake file     NaN  NaN   58
# 5     58         2      5  fake video       fake file     NaN  NaN   60
# 6     60         2      6  fake video       fake file     NaN  NaN   62
# 7     62        50      0  fake video       fake file     NaN  NaN  112
# 8    112         2      1  fake video       fake file     NaN  NaN  114
# 9    114         2      2  fake video       fake file     NaN  NaN  116
#
#                  Syntax  Ordered_State  Bout  Filtered_State
# 0          Not_Grooming              0   NaN               0
# 1              Paw_Lick              1   NaN               1
# 2   Bilateral_Face_Wash              2   NaN               2
# 3         Genital_Groom              3   NaN               3
# 4            Flank_Lick              4   NaN               4
# 5  Unilateral_Face_Wash              5   NaN               5
# 6            Tail_Groom              6   NaN               6
# 7          Not_Grooming              0   NaN               0
# 8              Paw_Lick              1   NaN               1
# 9   Bilateral_Face_Wash              2   NaN               2

# %%
print(np.max(fake['End']))
# Out:
# 620

# %%
# visualize fake data

bout_vis.manual_inspect_filtstate(fake, 0, (0, 620), (10, 5))

# %%
boutMachine = BoutMachine(fake_fpath, '123456')

# %%
log = boutMachine.run_machine(boutMachine.data)
# Out:
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True
# state read: 0 chain acc: 0 target val: 1 verify: False
# state read: 1 chain acc: 0 target val: 1 verify: True
# state read: 2 chain acc: 1 target val: 2 verify: True
# state read: 3 chain acc: 2 target val: 3 verify: True
# state read: 4 chain acc: 3 target val: 4 verify: True
# state read: 5 chain acc: 4 target val: 5 verify: True
# state read: 6 chain acc: 5 target val: 6 verify: True

# %%
print(boutMachine.target_chain)
# Out:
# 123456

# %%
print(log)
# Out:
# {1: (50, 62), 2: (112, 124), 3: (174, 186), 4: (236, 248), 5: (298, 310), 6: (360, 372), 7: (422, 434), 8: (484, 496), 9: (546, 558), 10: (608, 620)}

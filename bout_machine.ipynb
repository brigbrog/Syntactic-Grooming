# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from bout_machine import BoutMachine
import visualize.bout_vis as bout_vis
from FileCurtain import FileCurtain

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
groomFileCurtain = FileCurtain('/Users/brogab/Documents/JAXFell25/library/groom_pathlib.txt')

fakeFileCurtain = FileCurtain('/Users/brogab/Documents/JAXFell25/library/fake_pathlib.txt')

# %%
fake_fpath1 = fakeFileCurtain.fpaths['fake1']
fake_fpath2 = fakeFileCurtain.fpaths['fake2']
fake_fpath3 = fakeFileCurtain.fpaths['fake3']


asd_bouts_fpath = groomFileCurtain.fpaths['ASD_bouts']
bxd_bouts_fpath = groomFileCurtain.fpaths['BXD_bouts']
jab_bouts_fpath = groomFileCurtain.fpaths['JABS1200']

# %% [markdown]
# run for fake data

# %%
fake1 = pd.read_csv(fake_fpath1)

fake1.head(10)
# Out:
#    Start  Duration  State  Video_name NetworkFilename  Strain  Sex  End  \
# 0      0        50      0  fake video       fake file     NaN  NaN   50
# 1     50         2      1  fake video       fake file     NaN  NaN   52
# 2     52         2      2  fake video       fake file     NaN  NaN   54
# 3     54         2      3  fake video       fake file     NaN  NaN   56
# 4     56         2      4  fake video       fake file     NaN  NaN   58
# 5     58         2      5  fake video       fake file     NaN  NaN   60
# 6     60         2      6  fake video       fake file     NaN  NaN   62
# 7     62        50      0  fake video       fake file     NaN  NaN  112
# 8    112         2      1  fake video       fake file     NaN  NaN  114
# 9    114         2      2  fake video       fake file     NaN  NaN  116
#
#                  Syntax  Ordered_State  Bout  Filtered_State
# 0          Not_Grooming              0     0               0
# ...

# %%
print(np.max(fake1['End']))
# Out:
# 620

# %%
# visualize fake data

bout_vis.manual_inspect_filtstate(fake1, 0, (0, 620), (10, 5))

# %%
boutMachine = BoutMachine('123456')

# %%
log = boutMachine.single_vid_matchlog(fake1, verbose=False)

# %%
print(boutMachine.target_chain)
# Out:
# 123456

# %%
print(log)
# Out:
# ({'match_1': (50, 62), 'match_2': (112, 124), 'match_3': (174, 186), 'match_4': (236, 248), 'match_5': (298, 310), 'match_6': (360, 372), 'match_7': (422, 434), 'match_8': (484, 496), 'match_9': (546, 558), 'match_10': (608, 620)}, {'match_1': (1, 1), 'match_2': (2, 2), 'match_3': (3, 3), 'match_4': (4, 4), 'match_5': (5, 5), 'match_6': (6, 6), 'match_7': (7, 7), 'match_8': (8, 8), 'match_9': (9, 9), 'match_10': (10, 10)})

# %%
fake2 = pd.read_csv(fake_fpath2)
print(np.max(fake2['End']))
fake2.head(15)
# Out:
# 325
#     Start  Duration  State  Video_name NetworkFilename  Strain  Sex  End  \
# 0       0        10      0  fake video       fake file     NaN  NaN   10
# 1      10         5      1  fake video       fake file     NaN  NaN   15
# 2      15         5      2  fake video       fake file     NaN  NaN   20
# 3      20         5      3  fake video       fake file     NaN  NaN   25
# 4      25         5      0  fake video       fake file     NaN  NaN   30
# 5      30         5      2  fake video       fake file     NaN  NaN   35
# 6      35         5      3  fake video       fake file     NaN  NaN   40
# 7      40         5      4  fake video       fake file     NaN  NaN   45
# 8      45         5      0  fake video       fake file     NaN  NaN   50
# 9      50         5      4  fake video       fake file     NaN  NaN   55
# 10     55         5      5  fake video       fake file     NaN  NaN   60
# 11     60         5      6  fake video       fake file     NaN  NaN   65
# ...

# %%
bout_vis.manual_inspect_filtstate(fake2, 0, (0, 325), (10, 5))

# %%
boutMachine = BoutMachine('34045')
i_log, b_log = boutMachine.single_vid_matchlog(fake2, verbose=True)
print(boutMachine.target_chain)
print(i_log)
print(b_log)
# Out:
# state read: 0 chain acc: 0 target val: 3 s_verify: False
# state read: 1 chain acc: 0 target val: 3 s_verify: False
# state read: 2 chain acc: 0 target val: 3 s_verify: False
# state read: 3 chain acc: 0 target val: 3 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# state read: 0 chain acc: 1 target val: 4 s_verify: False
# MATCH FAILED (STATE): 20
# state read: 2 chain acc: 0 target val: 3 s_verify: False
# state read: 3 chain acc: 0 target val: 3 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# state read: 4 chain acc: 1 target val: 4 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# state read: 0 chain acc: 2 target val: 0 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# state read: 4 chain acc: 3 target val: 4 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# state read: 5 chain acc: 4 target val: 5 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# MATCH: (35, 60)
# ...

# %%
fake3 = pd.read_csv(fake_fpath3)
print(np.max(fake3['End']))
fake3.head(10)
# Out:
# 250
#    Start  Duration  State  Video_name NetworkFilename  Strain  Sex  End  \
# 0      0        10      0  fake video       fake file     NaN  NaN   10
# 1     10        10      1  fake video       fake file     NaN  NaN   20
# 2     20        10      2  fake video       fake file     NaN  NaN   30
# 3     30        10      3  fake video       fake file     NaN  NaN   40
# 4     40        10      4  fake video       fake file     NaN  NaN   50
# 5     50        10      0  fake video       fake file     NaN  NaN   60
# 6     60        10      1  fake video       fake file     NaN  NaN   70
# 7     70        10      2  fake video       fake file     NaN  NaN   80
# 8     80        10      3  fake video       fake file     NaN  NaN   90
# 9     90        10      4  fake video       fake file     NaN  NaN  100
#
#                 Syntax  Ordered_State  Bout  Filtered_State
# 0         Not_Grooming              0     0               0
# ...

# %%
bout_vis.manual_inspect_filtstate(fake3, 0, (0, 250), (10, 5))

# %%
boutMachine = BoutMachine('123')
i_log, b_log = boutMachine.single_vid_matchlog(fake3, verbose=True)
print(boutMachine.target_chain)
print(i_log)
print(b_log)
# Out:
# state read: 0 chain acc: 0 target val: 1 s_verify: False
# state read: 1 chain acc: 0 target val: 1 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# state read: 2 chain acc: 1 target val: 2 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# state read: 3 chain acc: 2 target val: 3 s_verify: True
# bout read: 1, target val: 1, b_verify: True
# MATCH: (10, 40)
# state read: 4 chain acc: 0 target val: 1 s_verify: False
# state read: 0 chain acc: 0 target val: 1 s_verify: False
# state read: 1 chain acc: 0 target val: 1 s_verify: True
# bout read: 2, target val: 2, b_verify: True
# state read: 2 chain acc: 1 target val: 2 s_verify: True
# bout read: 2, target val: 2, b_verify: True
# state read: 3 chain acc: 2 target val: 3 s_verify: True
# bout read: 2, target val: 2, b_verify: True
# MATCH: (60, 90)
# state read: 4 chain acc: 0 target val: 1 s_verify: False
# state read: 0 chain acc: 0 target val: 1 s_verify: False
# ...

# %%
res = boutMachine.verify_bout(0, 1)
print(res)
# Out:
# False

# %% [markdown]
# run single video on real data

# %%
bxd = pd.read_csv(bxd_bouts_fpath)
bxd.head(10)
# Out:
#    Start  Duration  State                                         Video_name  \
# 0      0      3782      6  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 1   3782       141      3  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 2   3923        87      6  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 3   4010        70      3  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 4   4080        16      6  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 5   4096        18      3  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 6   4114       118      6  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 7   4232        61      0  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 8   4293        49      3  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 9   4342        12      0  /projects/kumar-lab/bxd-survey-dataset/unalign...
#
#                                      NetworkFilename       Strain Sex   End  \
# ...

# %%
test_id = 0

bxd_vid1 = bxd[bxd['Video_name'] == np.unique(bxd['Video_name'])[test_id]]
bxd_vid1.shape
# Out:
# (329, 12)

# %%
print(np.unique(bxd_vid1['Video_name']))
range = np.max(bxd_vid1['End'])
print(range)
# Out:
# ['/projects/kumar-lab/bxd-survey-dataset/unaligned/LL1-B2B/2019-06-25_SPD/LL1-1_030878-M-AX10-8.71428571428571-43575-1-K19062002']
# 108000

# %%
bout_vis.manual_inspect_filtstate(bxd_vid1, 0, (0, range), (10, 5))

# %%
print(np.unique(bxd_vid1['Ordered_State']))
# Out:
# [0 1 2 3 4 5 6]

# %%
boutMachine = BoutMachine('12', use_filt_state=False)
i_log, b_log = boutMachine.single_vid_matchlog(bxd_vid1, verbose=False)
print(boutMachine.target_chain)
print(f'INT LOG: {i_log}')
print(f'BOUT LOG: {b_log}')
# Out:
# 12
# INT LOG: {'match_1': (34512, 34550), 'match_2': (46612, 46759), 'match_3': (47185, 47204), 'match_4': (59846, 60015), 'match_5': (70154, 70288), 'match_6': (70578, 70607), 'match_7': (93039, 93085), 'match_8': (99261, 99285)}
# BOUT LOG: {'match_1': (23, 23), 'match_2': (27, 27), 'match_3': (27, 27), 'match_4': (33, 33), 'match_5': (38, 38), 'match_6': (38, 38), 'match_7': (48, 48), 'match_8': (56, 56)}

# %%
inspect_range = (34512, 34550)

bout_vis.manual_inspect_filtstate(bxd_vid1, 0, inspect_range, (10, 5))

# %%
fake3.head(30)
# Out:
#     Start  Duration  State  Video_name NetworkFilename  Strain  Sex  End  \
# 0       0        10      0  fake video       fake file     NaN  NaN   10
# 1      10        10      1  fake video       fake file     NaN  NaN   20
# 2      20        10      2  fake video       fake file     NaN  NaN   30
# 3      30        10      3  fake video       fake file     NaN  NaN   40
# 4      40        10      4  fake video       fake file     NaN  NaN   50
# 5      50        10      0  fake video       fake file     NaN  NaN   60
# 6      60        10      1  fake video       fake file     NaN  NaN   70
# 7      70        10      2  fake video       fake file     NaN  NaN   80
# 8      80        10      3  fake video       fake file     NaN  NaN   90
# 9      90        10      4  fake video       fake file     NaN  NaN  100
# 10    100        10      0  fake video       fake file     NaN  NaN  110
# 11    110        10      1  fake video       fake file     NaN  NaN  120
# ...

# %%
print(fake3[fake3['Start'] == 0]['Bout'].iloc[0])
# Out:
# 0

# %%
fake_test_pull = boutMachine.pull_match_data(fake3,
                                        'fake video',
                                        {'match_1': (10, 40), 'match_2': (60, 90), 'match_3': (110, 140), 'match_4': (160, 190), 'match_5': (210, 240)},
                                        '123')

# %%
fake_test_pull = pd.DataFrame(fake_test_pull)
fake_test_pull.head()
# Out:
#   target  match_num    interval  bout_num  sex  strain      duration  \
# 0    123          1    (10, 40)         1  NaN     NaN  [10, 10, 10]
# 1    123          2    (60, 90)         2  NaN     NaN  [10, 10, 10]
# 2    123          3  (110, 140)         3  NaN     NaN  [10, 10, 10]
# 3    123          4  (160, 190)         4  NaN     NaN  [10, 10, 10]
# 4    123          5  (210, 240)         5  NaN     NaN  [10, 10, 10]
#
#   video_search_index  video_name
# 0               None  fake video
# 1               None  fake video
# 2               None  fake video
# 3               None  fake video
# 4               None  fake video

# %%
real_test_pull = boutMachine.pull_match_data(bxd_vid1,
                                        '/projects/kumar-lab/bxd-survey-dataset/unaligned/LL1-B2B/2019-06-25_SPD/LL1-1_030878-M-AX10-8.71428571428571-43575-1-K19062002',
                                        {'match_1': (34512, 34550), 'match_2': (46612, 46759), 'match_3': (47185, 47204), 'match_4': (59846, 60015), 'match_5': (70154, 70288), 'match_6': (70578, 70607), 'match_7': (93039, 93085), 'match_8': (99261, 99285)},
                                        '12')

# %%
real_test_pull = pd.DataFrame(real_test_pull)
real_test_pull.head(20)
# Out:
#   target  match_num        interval  bout_num sex       strain   duration  \
# 0     12          1  (34512, 34550)        23   M  BXD194/RwwJ   [21, 17]
# 1     12          2  (46612, 46759)        27   M  BXD194/RwwJ   [138, 9]
# 2     12          3  (47185, 47204)        27   M  BXD194/RwwJ    [8, 11]
# 3     12          4  (59846, 60015)        33   M  BXD194/RwwJ  [140, 29]
# 4     12          5  (70154, 70288)        38   M  BXD194/RwwJ   [87, 47]
# 5     12          6  (70578, 70607)        38   M  BXD194/RwwJ   [13, 16]
# 6     12          7  (93039, 93085)        48   M  BXD194/RwwJ    [39, 7]
# 7     12          8  (99261, 99285)        56   M  BXD194/RwwJ   [13, 11]
#
#   video_search_index                                         video_name
# 0               None  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 1               None  /projects/kumar-lab/bxd-survey-dataset/unalign...
# 2               None  /projects/kumar-lab/bxd-survey-dataset/unalign...
# ...

# %%
thing = np.array([1 , 2, 3, 4, 5])
ind = [0, 2]

print(thing[ind])
# Out:
# [1 3]

# %% [markdown]
# Run for multi vid matching

# %%
bxd = pd.read_csv(bxd_bouts_fpath)
bxd.shape
# Out:
# (306311, 12)

# %%
test_ids = [0, 1, 2, 3, 4]

boutMachine = BoutMachine('12', use_filt_state=False)

test_mv_match_log = boutMachine.multi_vid_matchlog(bxd, test_ids)

test_mv_match_log.head(25)
# Out:
#    target  match_num          interval  bout_num sex       strain   duration  \
# 0      12          1    (34512, 34550)        23   M  BXD194/RwwJ   [21, 17]
# 1      12          2    (46612, 46759)        27   M  BXD194/RwwJ   [138, 9]
# 2      12          3    (47185, 47204)        27   M  BXD194/RwwJ    [8, 11]
# 3      12          4    (59846, 60015)        33   M  BXD194/RwwJ  [140, 29]
# 4      12          5    (70154, 70288)        38   M  BXD194/RwwJ   [87, 47]
# 5      12          6    (70578, 70607)        38   M  BXD194/RwwJ   [13, 16]
# 6      12          7    (93039, 93085)        48   M  BXD194/RwwJ    [39, 7]
# 7      12          8    (99261, 99285)        56   M  BXD194/RwwJ   [13, 11]
# 8      12          1    (17686, 17704)         6   M  BXD194/RwwJ    [7, 11]
# 9      12          2    (18972, 19112)         8   M  BXD194/RwwJ  [130, 10]
# 10     12          3    (19112, 19135)         8   M  BXD194/RwwJ    [8, 15]
# ...

# %% [markdown]
# RESULT ANALYSIS FROM Multivideo

# %%
# first 5 video results

searchLogCurtain = FileCurtain('/Users/brogab/Documents/JAXFell25/library/searchLog_pathlib.txt')

# %%
bxd25 = pd.read_csv(searchLogCurtain.fpaths['BXD25'])

bxd25 = pd.read_csv(
    searchLogCurtain.fpaths['BXD25'], dtype={
        "target": "string",
        "match_num": "int",
        #"interval": "tuple",
        "bout_num": "int",
        "sex": "string",
        "strain": "string",
        #"duration": "list",
        "video_search_index": "int",
        "video_name": "string"
    }
)
#bxd25['target'] = bxd25['target'].astype(str)
print(bxd25.shape)
print(bxd25.dtypes)
bxd25.head()
# Out:
# (7144, 9)
# target                string[python]
# match_num                      int64
# interval                      object
# bout_num                       int64
# sex                   string[python]
# strain                string[python]
# duration                      object
# video_search_index             int64
# video_name            string[python]
# dtype: object
#   target  match_num        interval  bout_num sex       strain   duration  \
# 0     12          1  (34512, 34550)        23   M  BXD194/RwwJ    [21 17]
# 1     12          2  (46612, 46759)        27   M  BXD194/RwwJ  [138   9]
# 2     12          3  (47185, 47204)        27   M  BXD194/RwwJ    [ 8 11]
# 3     12          4  (59846, 60015)        33   M  BXD194/RwwJ  [140  29]
# 4     12          5  (70154, 70288)        38   M  BXD194/RwwJ    [87 47]
#
#    video_search_index                                         video_name
# 0                   0  /projects/kumar-lab/bxd-survey-dataset/unalign...
# ...

# %%
bxd25_strains = bxd25['strain'].unique()
print(bxd25_strains)
# Out:
# <StringArray>
# ['BXD194/RwwJ', 'BXD214/RwwJ',  'BXD44/RwwJ',   'BXD31/TyJ',   'BXD19/TyJ',
#  'BXD125/RwwJ']
# Length: 6, dtype: string

# %%
print(bxd25['target'].unique())
# Out:
# <StringArray>
# ['12', '13', '14', '15', '16', '10', '21', '23', '24', '25', '20', '31', '32',
#  '34', '35', '36', '30', '41', '42', '43', '45', '46', '40', '51', '52', '53',
#  '54', '56', '50', '61', '64', '65', '60', '01', '02', '03', '04', '05', '06']
# Length: 39, dtype: string

# %%
correct_trans_df = None
for idx, strain in enumerate(bxd25_strains):
    strain_slice = bxd25[bxd25['strain']==strain]
    #print(f'strain: {strain}, shape: {strain_slice.shape}')
    correct_trans_strain = {
        'strain': strain,
        #'total_trans': strain_slice.shape[0],
        '01': (strain_slice['target'] == '01').sum(),
        '12': (strain_slice['target'] == '12').sum(),
        '23': (strain_slice['target'] == '23').sum(),
        '34': (strain_slice['target'] == '34').sum(),
        '45': (strain_slice['target'] == '45').sum(),
        '56': (strain_slice['target'] == '56').sum(),
        '60': (strain_slice['target'] == '60').sum()
    }
    if idx == 0:
        correct_trans_df = pd.DataFrame([correct_trans_strain])
    else:
        correct_trans_df = pd.concat([correct_trans_df, pd.DataFrame([correct_trans_strain])], ignore_index=True)

# %%
correct_trans_df.head(6)
# Out:
#         strain   01  12  23  34   45  56   60
# 0  BXD194/RwwJ  122  22   2   2   20   1    2
# 1  BXD214/RwwJ   76  29   4  10   43   1    3
# 2   BXD44/RwwJ  140  20   8   9   59   4   10
# 3    BXD31/TyJ  155  26   3   0   55   1    5
# 4    BXD19/TyJ  304  54  11   6  164  26  100
# 5  BXD125/RwwJ  162  42   9  29  109   1   24

# %%
trans_ref = {
    'cor_all': ['01', '12', '23', '34', '45', '56', '60'],
    'incor0': ['02', '03', '04', '05', '06'],
    'incor1': ['13', '14', '15', '16', '10'],
    'incor2': ['21', '24', '25', '26', '20'],
    'incor3': ['31', '32', '35', '36', '30'],
    'incor4': ['41', '42', '43', '46', '40'],
    'incor5': ['51', '52', '53', '54', '50'],
    'incor6': ['61', '62', '63', '64', '65']
}

# %%
incor_trans_df = None
for idx, strain in enumerate(bxd25_strains):
    strain_slice = bxd25[bxd25['strain']==strain]
    #print(f'strain: {strain}, shape: {strain_slice.shape}')
    incor_trans_strain = {
        'strain': strain,
        #'total_trans': strain_slice.shape[0],
        'incor0': (strain_slice['target'].isin(trans_ref['incor0'])).sum(),
        'incor1': (strain_slice['target'].isin(trans_ref['incor1'])).sum(),
        'incor2': (strain_slice['target'].isin(trans_ref['incor2'])).sum(),
        'incor3': (strain_slice['target'].isin(trans_ref['incor3'])).sum(),
        'incor4': (strain_slice['target'].isin(trans_ref['incor4'])).sum(),
        'incor5': (strain_slice['target'].isin(trans_ref['incor5'])).sum(),
        'incor6': (strain_slice['target'].isin(trans_ref['incor6'])).sum()
    }
    if idx == 0:
        incor_trans_df = pd.DataFrame([incor_trans_strain])
    else:
        incor_trans_df = pd.concat([incor_trans_df, pd.DataFrame([incor_trans_strain])], ignore_index=True)

# %%
incor_trans_df.head(6)
# Out:
#         strain  incor0  incor1  incor2  incor3  incor4  incor5  incor6
# 0  BXD194/RwwJ     106     174      37      30      11     131       0
# 1  BXD214/RwwJ      67     189      62      52      56     113       6
# 2   BXD44/RwwJ     136     289      32     120      40     156      23
# 3    BXD31/TyJ     107     275      45      71      33     171       2
# 4    BXD19/TyJ     336     525      78     121     125     351     100
# 5  BXD125/RwwJ     135     399      63     154     144     179      27

# %%
incor_trans_df.dtypes
# Out:
# strain    object
# incor0     int64
# incor1     int64
# incor2     int64
# incor3     int64
# incor4     int64
# incor5     int64
# incor6     int64
# dtype: object

# %%
cor_mat = correct_trans_df.iloc[:, 1:].to_numpy(dtype=np.int64)
incor_mat = incor_trans_df.iloc[:, 1:].to_numpy(dtype=np.int64)

print(cor_mat)
print(incor_mat)

per_cor_trans_mat = 100 * cor_mat / (cor_mat + incor_mat)

print(per_cor_trans_mat)

per_cor_trans_mat.shape
# Out:
# [[122  22   2   2  20   1   2]
#  [ 76  29   4  10  43   1   3]
#  [140  20   8   9  59   4  10]
#  [155  26   3   0  55   1   5]
#  [304  54  11   6 164  26 100]
#  [162  42   9  29 109   1  24]]
# [[106 174  37  30  11 131   0]
#  [ 67 189  62  52  56 113   6]
#  [136 289  32 120  40 156  23]
#  [107 275  45  71  33 171   2]
#  [336 525  78 121 125 351 100]
#  [135 399  63 154 144 179  27]]
# [[ 53.50877193  11.2244898    5.12820513   6.25        64.51612903
#     0.75757576 100.        ]
#  [ 53.14685315  13.30275229   6.06060606  16.12903226  43.43434343
#     0.87719298  33.33333333]
#  [ 50.72463768   6.47249191  20.           6.97674419  59.5959596
#     2.5         30.3030303 ]
#  [ 59.16030534   8.63787375   6.25         0.          62.5
#     0.58139535  71.42857143]
#  [ 47.5          9.32642487  12.35955056   4.72440945  56.74740484
#     6.89655172  50.        ]
#  [ 54.54545455   9.52380952  12.5         15.84699454  43.08300395
#     0.55555556  47.05882353]]
# (6, 7)

# %%
# column names (your 7 transitions)
transitions = correct_trans_df.columns[1:]

# row labels (your 6 strains)
strains = correct_trans_df['strain']

# build dataframe
plot_df = pd.DataFrame(
    per_cor_trans_mat,
    index=strains,
    columns=transitions
).reset_index(names='strain')

# melt to long format
plot_df = plot_df.melt(
    id_vars='strain',
    var_name='transition',
    value_name='percent_correct'
)

# %%
plt.figure(figsize=(12, 6))

ax = sns.barplot(
        data=plot_df,
        x='transition',
        y='percent_correct',
        hue='strain'
    )

for container in ax.containers:
    ax.bar_label(
        container,
        fmt='%.0f',
        fontsize=10,
        #padding=0
    )

plt.ylabel('Percent Correct Transistions')
plt.xlabel('Transition')
plt.title('Percent Correct Transitions by Strain \n(first 25 videos in BXD)')
plt.legend(title='Strain')#, bbox_to_anchor=(1.05, 1))#, loc='upper left')

plt.tight_layout()
plt.show()
